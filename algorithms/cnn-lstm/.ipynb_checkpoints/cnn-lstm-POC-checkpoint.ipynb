# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.models import load_model
from keras.layers import Dropout,Conv1D, MaxPooling1D, Flatten,TimeDistributed,Bidirectional
import math
import datetime as dt
from datetime import datetime    
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
# %matplotlib inline
import math
from sklearn.preprocessing import MinMaxScaler

def import_data_from_csv(path: str):
    """
    Imports data from a csv file and returns a pandas dataframe.
    """
    return pd.read_csv(path)

# %%
data = import_data_from_csv("..\..\data\processed\AAPL.csv")

# %%
df = data

# %% [raw]
# The data has been analysed but it must be converted into data of shape [100,1] to make it easier for CNN to train on... Else it won't select necessary features and the model will fail

# %%
from sklearn.model_selection import train_test_split

X = []
Y = []
window_size=100
for i in range(1 , len(df) - window_size -1 , 1):
    first = df.iloc[i,2]
    temp = []
    temp2 = []
    for j in range(window_size):
        temp.append((df.iloc[i + j, 2] - first) / first)
    temp2.append((df.iloc[i + window_size, 2] - first) / first)
    X.append(np.array(temp).reshape(100, 1))
    Y.append(np.array(temp2).reshape(1, 1))

# x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=True)
train_X_values = []
test_X_values = []
train_Y_values = []
test_Y_values = []

num_splits = 5
split_size = len(X) / num_splits

X_splits = [X[int(i * split_size):int((i + 1) * split_size)] for i in range(num_splits)]
Y_splits = [Y[int(i * split_size):int((i + 1) * split_size)] for i in range(num_splits)]

    
for i in range(num_splits):
    x_train, x_test, y_train, y_test = train_test_split(X_splits[i], Y_splits[i], test_size=0.2, shuffle=True)
    train_X = np.array(x_train)
    test_X = np.array(x_test)
    train_Y = np.array(y_train)
    test_Y = np.array(y_test)
    
    train_X = train_X.reshape(train_X.shape[0],1,100,1)
    test_X = test_X.reshape(test_X.shape[0],1,100,1)
    
    train_X_values.append(train_X)
    test_X_values.append(test_X)
    train_Y_values.append(train_Y)
    test_Y_values.append(test_Y)

print("Done! Test and train data are ready")
# Out:
# Done! Test and train data are ready

# %%
# For creating model and training
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, Bidirectional, TimeDistributed
from tensorflow.keras.layers import MaxPooling1D, Flatten
from tensorflow.keras.regularizers import L1, L2
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.metrics import RootMeanSquaredError

model = tf.keras.Sequential()

# Creating the Neural Network model here...
# CNN layers
model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu', input_shape=(None, 100, 1))))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(128, kernel_size=3, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Conv1D(64, kernel_size=3, activation='relu')))
model.add(TimeDistributed(MaxPooling1D(2)))
model.add(TimeDistributed(Flatten()))

# LSTM layers
model.add(Bidirectional(LSTM(100, return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(100, return_sequences=False)))
model.add(Dropout(0.5))

#Final layers
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae'])

for i in range(len(train_X_values)):
    history = model.fit(train_X_values[i], train_Y_values[i], validation_data=(test_X_values[i],test_Y_values[i]), epochs=20,batch_size=40, verbose=1, shuffle =True)
    plt.plot(history.history['mse'], label='train mse '+str(i))
    plt.plot(history.history['val_mse'], label='val mse '+str(i))
    plt.xlabel("epoch")
    plt.ylabel("Loss")
    plt.legend()
    model.save("checkpoints/APPL/cnn-lstm-"+str(i+1)+".keras")
# Out:
# Epoch 1/20
# 13/13 [==============================] - 20s 305ms/step - loss: 0.0360 - mse: 0.0360 - mae: 0.1517 - val_loss: 0.0102 - val_mse: 0.0102 - val_mae: 0.0806
# Epoch 2/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0132 - mse: 0.0132 - mae: 0.0871 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0565
# Epoch 3/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0069 - mse: 0.0069 - mae: 0.0668 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0575
# Epoch 4/20
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0678 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0537
# Epoch 5/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0067 - mse: 0.0067 - mae: 0.0650 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0477
# Epoch 6/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0583 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0440
# Epoch 7/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0542 - val_loss: 0.0025 - val_mse: 0.0025 - val_mae: 0.0426
# Epoch 8/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0512 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0416
# Epoch 9/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0509 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0376
# Epoch 10/20
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0494 - val_loss: 0.0028 - val_mse: 0.0028 - val_mae: 0.0439
# Epoch 11/20
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0463 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0377
# Epoch 12/20
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0421 - val_loss: 0.0018 - val_mse: 0.0018 - val_mae: 0.0346
# Epoch 13/20
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0420 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0358
# Epoch 14/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0431 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0363
# Epoch 15/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0422 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0323
# Epoch 16/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0405 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0294
# Epoch 17/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0398 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0316
# Epoch 18/20
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0399 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0295
# Epoch 19/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0397 - val_loss: 0.0017 - val_mse: 0.0017 - val_mae: 0.0329
# Epoch 20/20
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0401 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0316
# Epoch 1/20
# 13/13 [==============================] - 1s 42ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0410 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0362
# Epoch 2/20
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0350 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0310
# Epoch 3/20
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0323 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0310
# Epoch 4/20
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0325 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0276
# Epoch 5/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0301 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0302
# Epoch 6/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0304 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0263
# Epoch 7/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0293 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0258
# Epoch 8/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0282 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0262
# Epoch 9/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0290 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0264
# Epoch 10/20
# 13/13 [==============================] - 1s 42ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0299 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0257
# Epoch 11/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0275 - val_loss: 9.6365e-04 - val_mse: 9.6365e-04 - val_mae: 0.0238
# Epoch 12/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0266 - val_loss: 9.6439e-04 - val_mse: 9.6439e-04 - val_mae: 0.0238
# Epoch 13/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0271 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0272
# Epoch 14/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0264 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0289
# Epoch 15/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0284 - val_loss: 8.9301e-04 - val_mse: 8.9301e-04 - val_mae: 0.0235
# Epoch 16/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0275 - val_loss: 9.6789e-04 - val_mse: 9.6789e-04 - val_mae: 0.0242
# Epoch 17/20
# 13/13 [==============================] - 0s 34ms/step - loss: 9.8432e-04 - mse: 9.8432e-04 - mae: 0.0252 - val_loss: 8.5502e-04 - val_mse: 8.5502e-04 - val_mae: 0.0225
# Epoch 18/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0253 - val_loss: 9.1137e-04 - val_mse: 9.1137e-04 - val_mae: 0.0238
# Epoch 19/20
# 13/13 [==============================] - 0s 34ms/step - loss: 9.7285e-04 - mse: 9.7285e-04 - mae: 0.0244 - val_loss: 9.8993e-04 - val_mse: 9.8993e-04 - val_mae: 0.0245
# Epoch 20/20
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0259 - val_loss: 8.7482e-04 - val_mse: 8.7482e-04 - val_mae: 0.0233
# Epoch 1/20
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0315 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0306
# Epoch 2/20
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0313 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0279
# Epoch 3/20
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0287 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0304
# Epoch 4/20
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0290 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0269
# Epoch 5/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0280 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0275
# Epoch 6/20
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0270 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0270
# Epoch 7/20
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0277 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0267
# Epoch 8/20
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0260 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0271
# Epoch 9/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0264 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0265
# Epoch 10/20
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0255 - val_loss: 0.0010 - val_mse: 0.0010 - val_mae: 0.0253
# Epoch 11/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0247 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0276
# Epoch 12/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0250 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0249
# Epoch 13/20
# 13/13 [==============================] - 0s 32ms/step - loss: 9.4885e-04 - mse: 9.4885e-04 - mae: 0.0238 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0271
# Epoch 14/20
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0251 - val_loss: 0.0010 - val_mse: 0.0010 - val_mae: 0.0253
# Epoch 15/20
# 13/13 [==============================] - 1s 45ms/step - loss: 9.5518e-04 - mse: 9.5518e-04 - mae: 0.0243 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0264
# Epoch 16/20
# 13/13 [==============================] - 0s 35ms/step - loss: 9.8649e-04 - mse: 9.8649e-04 - mae: 0.0249 - val_loss: 9.8257e-04 - val_mse: 9.8257e-04 - val_mae: 0.0250
# Epoch 17/20
# 13/13 [==============================] - 1s 39ms/step - loss: 8.4805e-04 - mse: 8.4805e-04 - mae: 0.0229 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0264
# Epoch 18/20
# 13/13 [==============================] - 0s 35ms/step - loss: 9.1916e-04 - mse: 9.1916e-04 - mae: 0.0239 - val_loss: 0.0010 - val_mse: 0.0010 - val_mae: 0.0252
# Epoch 19/20
# 13/13 [==============================] - 1s 38ms/step - loss: 9.3136e-04 - mse: 9.3136e-04 - mae: 0.0239 - val_loss: 9.4883e-04 - val_mse: 9.4883e-04 - val_mae: 0.0250
# Epoch 20/20
# 13/13 [==============================] - 0s 36ms/step - loss: 8.8503e-04 - mse: 8.8503e-04 - mae: 0.0229 - val_loss: 9.9874e-04 - val_mse: 9.9874e-04 - val_mae: 0.0253
# Epoch 1/20
# 13/13 [==============================] - 1s 42ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0552 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0620
# Epoch 2/20
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0061 - mse: 0.0061 - mae: 0.0549 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0458
# Epoch 3/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0056 - mse: 0.0056 - mae: 0.0545 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0469
# Epoch 4/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0501 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0425
# Epoch 5/20
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0509 - val_loss: 0.0063 - val_mse: 0.0063 - val_mae: 0.0559
# Epoch 6/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0061 - mse: 0.0061 - mae: 0.0555 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0525
# Epoch 7/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0523 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0413
# Epoch 8/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0493 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0414
# Epoch 9/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0498 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0443
# Epoch 10/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0480 - val_loss: 0.0027 - val_mse: 0.0027 - val_mae: 0.0377
# Epoch 11/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0418 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0407
# Epoch 12/20
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0423 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0362
# Epoch 13/20
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0413 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0425
# Epoch 14/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0422 - val_loss: 0.0022 - val_mse: 0.0022 - val_mae: 0.0344
# Epoch 15/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0417 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0316
# Epoch 16/20
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0388 - val_loss: 0.0023 - val_mse: 0.0023 - val_mae: 0.0370
# Epoch 17/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0394 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0351
# Epoch 18/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0368 - val_loss: 0.0024 - val_mse: 0.0024 - val_mae: 0.0349
# Epoch 19/20
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0398 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0342
# Epoch 20/20
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0375 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0440
# Epoch 1/20
# 13/13 [==============================] - 1s 42ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0428 - val_loss: 0.0020 - val_mse: 0.0020 - val_mae: 0.0368
# Epoch 2/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0376 - val_loss: 0.0025 - val_mse: 0.0025 - val_mae: 0.0423
# Epoch 3/20
# 13/13 [==============================] - 0s 39ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0358 - val_loss: 0.0014 - val_mse: 0.0014 - val_mae: 0.0312
# Epoch 4/20
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0309 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0283
# Epoch 5/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0291 - val_loss: 0.0010 - val_mse: 0.0010 - val_mae: 0.0261
# Epoch 6/20
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0288 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0278
# Epoch 7/20
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0288 - val_loss: 9.6119e-04 - val_mse: 9.6119e-04 - val_mae: 0.0257
# Epoch 8/20
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0275 - val_loss: 9.1394e-04 - val_mse: 9.1394e-04 - val_mae: 0.0240
# Epoch 9/20
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0273 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0277
# Epoch 10/20
# 13/13 [==============================] - 1s 36ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0284 - val_loss: 0.0012 - val_mse: 0.0012 - val_mae: 0.0294
# Epoch 11/20
# 13/13 [==============================] - 1s 42ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0273 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0279
# Epoch 12/20
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0261 - val_loss: 9.2369e-04 - val_mse: 9.2369e-04 - val_mae: 0.0254
# Epoch 13/20
# 13/13 [==============================] - 1s 44ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0258 - val_loss: 9.5348e-04 - val_mse: 9.5348e-04 - val_mae: 0.0259
# Epoch 14/20
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0262 - val_loss: 8.5955e-04 - val_mse: 8.5955e-04 - val_mae: 0.0232
# Epoch 15/20
# 13/13 [==============================] - 1s 42ms/step - loss: 9.7152e-04 - mse: 9.7152e-04 - mae: 0.0251 - val_loss: 8.0426e-04 - val_mse: 8.0426e-04 - val_mae: 0.0232
# Epoch 16/20
# 13/13 [==============================] - 0s 36ms/step - loss: 8.7895e-04 - mse: 8.7895e-04 - mae: 0.0236 - val_loss: 8.4736e-04 - val_mse: 8.4736e-04 - val_mae: 0.0236
# Epoch 17/20
# 13/13 [==============================] - 0s 36ms/step - loss: 9.6027e-04 - mse: 9.6027e-04 - mae: 0.0247 - val_loss: 8.5473e-04 - val_mse: 8.5473e-04 - val_mae: 0.0241
# Epoch 18/20
# 13/13 [==============================] - 0s 38ms/step - loss: 9.6372e-04 - mse: 9.6372e-04 - mae: 0.0250 - val_loss: 7.7977e-04 - val_mse: 7.7977e-04 - val_mae: 0.0223
# Epoch 19/20
# 13/13 [==============================] - 1s 43ms/step - loss: 9.2627e-04 - mse: 9.2627e-04 - mae: 0.0242 - val_loss: 7.6679e-04 - val_mse: 7.6679e-04 - val_mae: 0.0222
# Epoch 20/20
# 13/13 [==============================] - 1s 39ms/step - loss: 9.0682e-04 - mse: 9.0682e-04 - mae: 0.0243 - val_loss: 7.7980e-04 - val_mse: 7.7980e-04 - val_mae: 0.0228

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDist  (None, 1, 98, 64)         256
#  ributed)
#
#  time_distributed_1 (TimeDi  (None, 1, 49, 64)         0
#  stributed)
#
#  time_distributed_2 (TimeDi  (None, 1, 47, 128)        24704
#  stributed)
#
#  time_distributed_3 (TimeDi  (None, 1, 23, 128)        0
#  stributed)
#
#  time_distributed_4 (TimeDi  (None, 1, 21, 64)         24640
#  stributed)
#
#  time_distributed_5 (TimeDi  (None, 1, 10, 64)         0
#  stributed)
#
#  time_distributed_6 (TimeDi  (None, 1, 640)            0
#  stributed)
#
#  bidirectional (Bidirection  (None, 1, 200)            592800
#  al)
#
#  dropout (Dropout)           (None, 1, 200)            0
#
#  bidirectional_1 (Bidirecti  (None, 200)               240800
#  onal)
#
#  dropout_1 (Dropout)         (None, 200)               0
#
#  dense (Dense)               (None, 1)                 201
#
# =================================================================
# Total params: 883401 (3.37 MB)
# Trainable params: 883401 (3.37 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model.evaluate(test_X, test_Y)
# Out:
# 6/6 [==============================] - 0s 9ms/step - loss: 4.9763e-04 - mse: 4.9763e-04 - mae: 0.0172
# [0.0004976342897862196, 0.0004976342897862196, 0.017226267606019974]

# %%
from sklearn.metrics import explained_variance_score, mean_poisson_deviance, mean_gamma_deviance
from sklearn.metrics import r2_score
from sklearn.metrics import max_error

# predict probabilities for test set
yhat_probs = model.predict(test_X, verbose=0)
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]

var = explained_variance_score(test_Y.reshape(-1,1), yhat_probs)
print('Variance: %f' % var)

r2 = r2_score(test_Y.reshape(-1,1), yhat_probs)
print('R2 Score: %f' % var)

var2 = max_error(test_Y.reshape(-1,1), yhat_probs)
print('Max Error: %f' % var2)
# Out:
# Variance: 0.965071
# R2 Score: 0.965071
# Max Error: 0.087016

# %%
# predicted  = model.predict(test_X)
# test_label = test_Y.reshape(-1,1)
# predicted = np.array(predicted[:,0]).reshape(-1,1)
# len_t = len(train_X)
# for j in range(len_t , len_t + len(test_X)):
#     temp = data.iloc[j,3]
#     test_label[j - len_t] = test_label[j - len_t] * temp + temp
#     predicted[j - len_t] = predicted[j - len_t] * temp + temp
# plt.plot(test_label, color = 'red', label = 'Real Stock Price')
# plt.plot(predicted, color = 'green', label = 'Predicted  Stock Price')
# plt.title(' Stock Price Prediction')
# plt.xlabel('Time')
# plt.ylabel(' Stock Price')
# plt.legend()
# plt.show()

# %%
model.save("cnn-lstm.keras")

# %%
# Load model
new_model = tf.keras.models.load_model("checkpoints/APPL/cnn-lstm-1.keras")
new_model2 = tf.keras.models.load_model("checkpoints/APPL/cnn-lstm-2.keras")
new_model3 = tf.keras.models.load_model("checkpoints/APPL/cnn-lstm-3.keras")
new_model4 = tf.keras.models.load_model("checkpoints/APPL/cnn-lstm-4.keras")
new_model5 = tf.keras.models.load_model("checkpoints/APPL/cnn-lstm-5.keras")

# %%
print("Loading data ...")
data2 = import_data_from_csv("..\..\data\processed\AAPL.csv")
# Any CSV or TXT file can be added here....
data2.dropna(inplace=True)
data2.reset_index(drop=True, inplace=True)
df2 = data2.drop('Date', axis=1)

X = []
Y = []
print("Analyse data ...")
window_size=100
for i in range(1 , len(df2) - window_size -1 , 1):
    first = df2.iloc[i,4]
    temp = []
    temp2 = []
    for j in range(window_size):
        temp.append((df2.iloc[i + j, 4] - first) / first)
    # for j in range(week):
    temp2.append((df2.iloc[i + window_size, 4] - first) / first)
    X.append(np.array(temp).reshape(100, 1))
    Y.append(np.array(temp2).reshape(1, 1))

test_X = np.array(X)
test_Y = np.array(Y)

test_X = test_X.reshape(test_X.shape[0],1,100,1)

print("Predicting ...")
new_model.evaluate(test_X, test_Y)
new_model2.evaluate(test_X, test_Y)
new_model3.evaluate(test_X, test_Y)
new_model4.evaluate(test_X, test_Y)
new_model5.evaluate(test_X, test_Y)

predicted  = new_model5.predict(test_X)
test_label = test_Y.reshape(-1,1)
predicted = np.array(predicted[:,0]).reshape(-1,1)
len_t = len(test_X)
print(len_t)
for j in range(len_t):
    temp = data2.iloc[j,3]
    test_label[j - len_t] = test_label[j - len_t] * temp + temp
    predicted[j - len_t] = predicted[j - len_t] * temp + temp
plt.plot(test_label, color = 'red', label = 'Real Stock Price')
plt.plot(predicted, color = 'green', label = 'Predicted  Stock Price')
plt.title(' Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel(' Stock Price')
plt.legend()
plt.show()
# Out:
# Loading data ...
# Analyse data ...
# Predicting ...
# 99/99 [==============================] - 1s 8ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0470
# 99/99 [==============================] - 1s 8ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0421
# 99/99 [==============================] - 1s 8ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0416
# 99/99 [==============================] - 1s 8ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0430
# 99/99 [==============================] - 1s 8ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0378
# 99/99 [==============================] - 1s 8ms/step
# 3160
